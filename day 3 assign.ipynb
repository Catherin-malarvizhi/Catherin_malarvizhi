# %%
#population by country
import pandas as pd
sf=pd.read_csv(r"C:\Users\mccmrfcs\Downloads\population_by_county.csv - population_by_county.csv.csv")
print (sf)
# Out:
#                 County           State  2010Census  2017PopEstimate
# 0     Abbeville County  South Carolina       25417            24722
# 1        Acadia Parish       Louisiana       61773            62590
# 2      Accomack County        Virginia       33164            32545
# 3           Ada County           Idaho      392365           456849
# 4         Adair County            Iowa        7682             7054
# ...                ...             ...         ...              ...
# 3137       Yuma County         Arizona      195751           207534
# 3138       Yuma County        Colorado       10043            10075
# 3139     Zapata County           Texas       14018            14322
# 3140     Zavala County           Texas       11677            11948
# 3141    Ziebach County    South Dakota        2801             2756
#
# [3142 rows x 4 columns]

# %%
import numpy as np

# %%
sf.head()
# Out:
#              County           State  2010Census  2017PopEstimate
# 0  Abbeville County  South Carolina       25417            24722
# 1     Acadia Parish       Louisiana       61773            62590
# 2   Accomack County        Virginia       33164            32545
# 3        Ada County           Idaho      392365           456849
# 4      Adair County            Iowa        7682             7054

# %%
#to find columns names
sf.columns
# Out:
# Index(['County', 'State', '2010Census', '2017PopEstimate'], dtype='object')

# %%
#to find states
States=sf['State'].count()
print(States)
# Out:
# 3142

# %%
#list of all thes states
list=sf['State'].tolist()
list
# Out:
# ['South Carolina',
#  'Louisiana',
#  'Virginia',
#  'Idaho',
#  'Iowa',
#  'Kentucky',
#  'Missouri',
#  'Oklahoma',
#  'Colorado',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Mississippi',
#  'Nebraska',
#  'North Dakota',
#  'Ohio',
#  'Pennsylvania',
#  'Washington',
#  'Wisconsin',
#  'Vermont',
#  'South Carolina',
#  'Minnesota',
#  'Florida',
#  'North Carolina',
#  'California',
#  'Colorado',
#  'New York',
#  'Wyoming',
#  'Virginia',
#  'Michigan',
#  'Mississippi',
#  'Alaska',
#  'Alaska',
#  'Illinois',
#  'North Carolina',
#  'Virginia',
#  'Oklahoma',
#  'Michigan',
#  'Iowa',
#  'Michigan',
#  'Maryland',
#  'New York',
#  'North Carolina',
#  'Virginia',
#  'Pennsylvania',
#  'Indiana',
#  'Kansas',
#  'Kentucky',
#  'Ohio',
#  'Louisiana',
#  'South Carolina',
#  'Michigan',
#  'California',
#  'California',
#  'Virginia',
#  'Virginia',
#  'Mississippi',
#  'Alaska',
#  'Kansas',
#  'Kentucky',
#  'South Carolina',
#  'Tennessee',
#  'Texas',
# ...

# %%
#5 country names
common_countries=sf['County'].value_counts().head(5)
common_countries
# Out:
# County
# Washington County    30
# Jefferson County     25
# Franklin County      24
# Lincoln County       23
# Jackson County       23
# Name: count, dtype: int64

# %%
#what are the top 5 most populated Countries according to the 2010 census?
most_populated_countries=sf['2010Census'].nlargest(5)
most_populated_countries
# Out:
# 1713    9818605
# 628     5194675
# 1209    4092459
# 1784    3817117
# 2501    3095313
# Name: 2010Census, dtype: int64

# %%
#how many countyries have 2010 populations greater than 1 million
len(sf[sf['2010Census']>1000000])
# Out:
# 39

# %%
sf['new_col = (2010Census - 2017PopEstimate)/100']=(sf['2010Census'] - sf['2017PopEstimate'])/100
sf
# Out:
#                 County           State  2010Census  2017PopEstimate  \
# 0     Abbeville County  South Carolina       25417            24722
# 1        Acadia Parish       Louisiana       61773            62590
# 2      Accomack County        Virginia       33164            32545
# 3           Ada County           Idaho      392365           456849
# 4         Adair County            Iowa        7682             7054
# ...                ...             ...         ...              ...
# 3137       Yuma County         Arizona      195751           207534
# 3138       Yuma County        Colorado       10043            10075
# 3139     Zapata County           Texas       14018            14322
# 3140     Zavala County           Texas       11677            11948
# 3141    Ziebach County    South Dakota        2801             2756
#
#       new_col = (2010Census - 2017PopEstimate)/100
# 0                                             6.95
# ...

# %%
from scipy.stats import pearsonr
corr,_=pearsonr(sf['2010Census'],sf['2017PopEstimate'])
corr
# Out:
# 0.9987582035845396

# %%
#part B
#gold GLD,nifty NIFTY
import yfinance as yf
gold = yf.Ticker("GLD").history(start="2023-03-13",end="2023-04-13")
gold
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-03-13 00:00:00-04:00  176.660004  178.020004  176.300003  177.860001
# 2023-03-14 00:00:00-04:00  177.350006  177.589996  176.210007  176.830002
# 2023-03-15 00:00:00-04:00  178.860001  180.130005  177.490005  178.210007
# 2023-03-16 00:00:00-04:00  179.509995  179.649994  177.869995  178.570007
# 2023-03-17 00:00:00-04:00  181.020004  184.809998  180.770004  183.770004
# 2023-03-20 00:00:00-04:00  184.190002  184.539993  182.740005  183.839996
# 2023-03-21 00:00:00-04:00  182.649994  182.729996  179.899994  180.369995
# 2023-03-22 00:00:00-04:00  180.399994  183.940002  180.279999  183.440002
# 2023-03-23 00:00:00-04:00  183.910004  186.240005  183.600006  185.740005
# 2023-03-24 00:00:00-04:00  185.610001  185.990005  183.619995  183.649994
# 2023-03-27 00:00:00-04:00  181.149994  182.149994  180.690002  181.949997
# 2023-03-28 00:00:00-04:00  182.309998  183.619995  182.119995  183.440002
# ...

# %%
import pandas as pd
gold_1D = gold.values.flatten()
gold_1D
# Out:
# array([1.76660004e+02, 1.78020004e+02, 1.76300003e+02, 1.77860001e+02,
#        2.05544000e+07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.77350006e+02, 1.77589996e+02, 1.76210007e+02, 1.76830002e+02,
#        1.00190000e+07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.78860001e+02, 1.80130005e+02, 1.77490005e+02, 1.78210007e+02,
#        1.45461000e+07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.79509995e+02, 1.79649994e+02, 1.77869995e+02, 1.78570007e+02,
#        1.07622000e+07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.81020004e+02, 1.84809998e+02, 1.80770004e+02, 1.83770004e+02,
#        2.41563000e+07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.84190002e+02, 1.84539993e+02, 1.82740005e+02, 1.83839996e+02,
#        1.18457000e+07, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.82649994e+02, 1.82729996e+02, 1.79899994e+02, 1.80369995e+02,
# ...

# %%
series =pd.Series(gold_1D)
series
# Out:
# 0      1.766600e+02
# 1      1.780200e+02
# 2      1.763000e+02
# 3      1.778600e+02
# 4      2.055440e+07
#            ...
# 171    1.871900e+02
# 172    1.000090e+07
# 173    0.000000e+00
# 174    0.000000e+00
# 175    0.000000e+00
# Length: 176, dtype: float64

# %%
nifty = yf.Ticker("^NSEI").history(start="2023-03-13",end="2023-04-13")
nifty
# Out:
#                                    Open          High           Low  \
# Date
# 2023-03-13 00:00:00+05:30  17421.900391  17529.900391  17113.449219
# 2023-03-14 00:00:00+05:30  17160.550781  17224.650391  16987.099609
# 2023-03-15 00:00:00+05:30  17166.449219  17211.349609  16938.900391
# 2023-03-16 00:00:00+05:30  16994.650391  17062.449219  16850.150391
# 2023-03-17 00:00:00+05:30  17111.800781  17145.800781  16958.150391
# 2023-03-20 00:00:00+05:30  17066.599609  17066.599609  16828.349609
# 2023-03-21 00:00:00+05:30  17060.400391  17127.699219  17016.000000
# 2023-03-22 00:00:00+05:30  17177.449219  17207.250000  17107.849609
# 2023-03-23 00:00:00+05:30  17097.400391  17205.400391  17045.300781
# 2023-03-24 00:00:00+05:30  17076.199219  17109.449219  16917.349609
# 2023-03-27 00:00:00+05:30  16984.300781  17091.000000  16918.550781
# 2023-03-28 00:00:00+05:30  17031.750000  17061.750000  16913.750000
# 2023-03-29 00:00:00+05:30  16977.300781  17126.150391  16940.599609
# ...

# %%
nifty_1D = nifty.values.flatten()
nifty
# Out:
#                                    Open          High           Low  \
# Date
# 2023-03-13 00:00:00+05:30  17421.900391  17529.900391  17113.449219
# 2023-03-14 00:00:00+05:30  17160.550781  17224.650391  16987.099609
# 2023-03-15 00:00:00+05:30  17166.449219  17211.349609  16938.900391
# 2023-03-16 00:00:00+05:30  16994.650391  17062.449219  16850.150391
# 2023-03-17 00:00:00+05:30  17111.800781  17145.800781  16958.150391
# 2023-03-20 00:00:00+05:30  17066.599609  17066.599609  16828.349609
# 2023-03-21 00:00:00+05:30  17060.400391  17127.699219  17016.000000
# 2023-03-22 00:00:00+05:30  17177.449219  17207.250000  17107.849609
# 2023-03-23 00:00:00+05:30  17097.400391  17205.400391  17045.300781
# 2023-03-24 00:00:00+05:30  17076.199219  17109.449219  16917.349609
# 2023-03-27 00:00:00+05:30  16984.300781  17091.000000  16918.550781
# 2023-03-28 00:00:00+05:30  17031.750000  17061.750000  16913.750000
# 2023-03-29 00:00:00+05:30  16977.300781  17126.150391  16940.599609
# ...

# %%
series=pd.Series(nifty_1D)
series
# Out:
# 0       17421.900391
# 1       17529.900391
# 2       17113.449219
# 3       17154.300781
# 4      254900.000000
#            ...
# 135     17717.250000
# 136     17812.400391
# 137    232800.000000
# 138         0.000000
# 139         0.000000
# Length: 140, dtype: float64

# %%
#load gold and nifty 50 closing prices(march 13 - april 13,2023) into pandas series. print the first 5 prices for each and their data ty7pes
gold_close=gold['Close']
print(gold_close)
# Out:
# Date
# 2023-03-13 00:00:00-04:00    177.860001
# 2023-03-14 00:00:00-04:00    176.830002
# 2023-03-15 00:00:00-04:00    178.210007
# 2023-03-16 00:00:00-04:00    178.570007
# 2023-03-17 00:00:00-04:00    183.770004
# 2023-03-20 00:00:00-04:00    183.839996
# 2023-03-21 00:00:00-04:00    180.369995
# 2023-03-22 00:00:00-04:00    183.440002
# 2023-03-23 00:00:00-04:00    185.740005
# 2023-03-24 00:00:00-04:00    183.649994
# 2023-03-27 00:00:00-04:00    181.949997
# 2023-03-28 00:00:00-04:00    183.440002
# 2023-03-29 00:00:00-04:00    182.529999
# 2023-03-30 00:00:00-04:00    184.179993
# 2023-03-31 00:00:00-04:00    183.220001
# 2023-04-03 00:00:00-04:00    184.539993
# 2023-04-04 00:00:00-04:00    187.979996
# 2023-04-05 00:00:00-04:00    187.830002
# 2023-04-06 00:00:00-04:00    186.490005
# 2023-04-10 00:00:00-04:00    185.110001
# 2023-04-11 00:00:00-04:00    186.279999
# 2023-04-12 00:00:00-04:00    187.190002
# Name: Close, dtype: float64

# %%
gold_close_1D = gold_close.values.flatten()
print(gold_close_1D)
# Out:
# [177.86000061 176.83000183 178.21000671 178.57000732 183.77000427
#  183.83999634 180.36999512 183.44000244 185.74000549 183.6499939
#  181.94999695 183.44000244 182.52999878 184.17999268 183.22000122
#  184.53999329 187.97999573 187.83000183 186.49000549 185.11000061
#  186.27999878 187.19000244]

# %%
series=pd.Series(gold_close_1D)
series
# Out:
# 0     177.860001
# 1     176.830002
# 2     178.210007
# 3     178.570007
# 4     183.770004
# 5     183.839996
# 6     180.369995
# 7     183.440002
# 8     185.740005
# 9     183.649994
# 10    181.949997
# 11    183.440002
# 12    182.529999
# 13    184.179993
# 14    183.220001
# 15    184.539993
# 16    187.979996
# 17    187.830002
# 18    186.490005
# 19    185.110001
# 20    186.279999
# 21    187.190002
# dtype: float64

# %%
top_5= series.head(5)
top_5
# Out:
# 0    177.860001
# 1    176.830002
# 2    178.210007
# 3    178.570007
# 4    183.770004
# dtype: float64

# %%
nifty_close = nifty['Close']
print(nifty_close)
# Out:
# Date
# 2023-03-13 00:00:00+05:30    17154.300781
# 2023-03-14 00:00:00+05:30    17043.300781
# 2023-03-15 00:00:00+05:30    16972.150391
# 2023-03-16 00:00:00+05:30    16985.599609
# 2023-03-17 00:00:00+05:30    17100.050781
# 2023-03-20 00:00:00+05:30    16988.400391
# 2023-03-21 00:00:00+05:30    17107.500000
# 2023-03-22 00:00:00+05:30    17151.900391
# 2023-03-23 00:00:00+05:30    17076.900391
# 2023-03-24 00:00:00+05:30    16945.050781
# 2023-03-27 00:00:00+05:30    16985.699219
# 2023-03-28 00:00:00+05:30    16951.699219
# 2023-03-29 00:00:00+05:30    17080.699219
# 2023-03-31 00:00:00+05:30    17359.750000
# 2023-04-03 00:00:00+05:30    17398.050781
# 2023-04-05 00:00:00+05:30    17557.050781
# 2023-04-06 00:00:00+05:30    17599.150391
# 2023-04-10 00:00:00+05:30    17624.050781
# 2023-04-11 00:00:00+05:30    17722.300781
# 2023-04-12 00:00:00+05:30    17812.400391
# Name: Close, dtype: float64

# %%
nifty_close_1D = nifty_close.values.flatten()
print(nifty_close_1D)
# Out:
# [17154.30078125 17043.30078125 16972.15039062 16985.59960938
#  17100.05078125 16988.40039062 17107.5        17151.90039062
#  17076.90039062 16945.05078125 16985.69921875 16951.69921875
#  17080.69921875 17359.75       17398.05078125 17557.05078125
#  17599.15039062 17624.05078125 17722.30078125 17812.40039062]

# %%
series= pd.Series(nifty_close_1D)
series
# Out:
# 0     17154.300781
# 1     17043.300781
# 2     16972.150391
# 3     16985.599609
# 4     17100.050781
# 5     16988.400391
# 6     17107.500000
# 7     17151.900391
# 8     17076.900391
# 9     16945.050781
# 10    16985.699219
# 11    16951.699219
# 12    17080.699219
# 13    17359.750000
# 14    17398.050781
# 15    17557.050781
# 16    17599.150391
# 17    17624.050781
# 18    17722.300781
# 19    17812.400391
# dtype: float64

# %%
#load gold and Nifty prices and check their lengths. If unequal,align them by selecting common dates using index.intersection.print the aligned Series
Series_gold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[95], line 2
#       1 #load gold and Nifty prices and check their lengths. If unequal,align them by selecting common dates using index.intersection.print the aligned Series
# ----> 2 Series_gold
#
# NameError: name 'Series_gold' is not defined

# %%
S
